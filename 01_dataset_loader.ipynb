# %%
import os

print(os.listdir("MVSA_Single"))
print(os.listdir("MVSA_Single/data")[:10])
# Out:
# ['labelResultAll.txt', '.DS_Store', 'data']
# ['63.jpg', '3644.txt', '823.jpg', '4217.jpg', '1053.txt', '3578.jpg', '2666.jpg', '5109.jpg', '2100.jpg', '1735.txt']

# %%
with open("MVSA_Single/labelResultAll.txt", "r", encoding="utf-8", errors="ignore") as f:
    for i in range(10):
        print(f.readline().strip())
# Out:
# ID	text,image
# 1	neutral,positive
# 2	neutral,positive
# 3	neutral,positive
# 4	positive,positive
# 5	positive,positive
# 6	positive,positive
# 7	positive,positive
# 8	neutral,positive
# 9	positive,positive

# %%
import os
import pandas as pd

def load_mvsa_dataset(base_path="MVSA_Single"):
    label_file = os.path.join(base_path, "labelResultAll.txt")
    data_dir = os.path.join(base_path, "data")

    records = []

    with open(label_file, "r", encoding="utf-8", errors="ignore") as f:
        lines = f.readlines()

    # Skip header
    for line in lines[1:]:
        parts = line.strip().split("\t")

        if len(parts) != 2:
            continue

        img_id = parts[0]
        sentiments = parts[1].split(",")

        if len(sentiments) != 2:
            continue

        text_sentiment = sentiments[0].strip().lower()

        # Map sentiment to label
        label_map = {
            "negative": 0,
            "neutral": 1,
            "positive": 2
        }

        if text_sentiment not in label_map:
            continue

        text_path = os.path.join(data_dir, f"{img_id}.txt")
        image_path = os.path.join(data_dir, f"{img_id}.jpg")

        if not os.path.exists(text_path) or not os.path.exists(image_path):
            continue

        with open(text_path, "r", encoding="utf-8", errors="ignore") as t:
            text = t.read().strip()

        records.append({
            "id": img_id,
            "text": text,
            "image_path": image_path,
            "label": label_map[text_sentiment]
        })

    return pd.DataFrame(records)

# %%
# Out:
#   id                                               text  \
# 0  1       How I feel today #legday #jelly #aching #gym
# 1  2  grattis min griskulting!!!???? va bara tvungen...
# 2  3  RT @polynminion: The moment I found my favouri...
# 3  4  #escort We have a young and energetic team and...
# 4  5  RT @chrisashaffer: Went to SSC today to be a "...
#
#                image_path  label
# 0  MVSA_Single/data/1.jpg      1
# 1  MVSA_Single/data/2.jpg      1
# 2  MVSA_Single/data/3.jpg      1
# 3  MVSA_Single/data/4.jpg      2
# 4  MVSA_Single/data/5.jpg      2
# (4869, 4)
# label
# 1    1921
# 2    1731
# 0    1217
# Name: count, dtype: int64
